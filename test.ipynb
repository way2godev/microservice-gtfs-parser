# %%
import os
import pandas as pd

# %%
# rename the stops.txt if it is not in the correct format
if not os.path.exists('./data/stops.csv'):
    if os.path.exists('./data/stops.txt'):
        os.rename('./data/stops.txt', './data/stops.csv')
    else:
        raise FileNotFoundError('stops.csv not found')

stops = pd.read_csv('./data/stops.csv')

# %%
from parse.stops import parse_stops

parse_stops(stops)
# Out:
# 1/803(0.12%) - Barcelona-Sants
# 2/803(0.25%) - Cartagena
# 3/803(0.37%) - Torre-Pacheco
# 4/803(0.50%) - Balsicas-Mar Menor
# 5/803(0.62%) - Murcia
# 6/803(0.75%) - Orihuela-Miguel Hernandez
# 7/803(0.87%) - Elche Parque/elx Parc
# 8/803(1.00%) - Alicante/alacant
# 9/803(1.12%) - Elda-Petrer
# 10/803(1.25%) - Villena
# 11/803(1.37%) - Xativa
# 12/803(1.49%) - Valencia-Estacio del Nord
# 13/803(1.62%) - Castello
# 14/803(1.74%) - Benicassim
# 15/803(1.87%) - Benicarlo-Penyiscola
# 16/803(1.99%) - Vinaros
# 17/803(2.12%) - Laldea-Amposta-Tortosa
# 18/803(2.24%) - Cambrils
# 19/803(2.37%) - Tarragona
# 20/803(2.49%) - Madrid-Chamartin
# 21/803(2.62%) - Badajoz
# 22/803(2.74%) - Montijo
# 23/803(2.86%) - Merida
# 24/803(2.99%) - Caceres
# 25/803(3.11%) - Monfrague
# 26/803(3.24%) - Navalmoral de La Mata
# 27/803(3.36%) - Oropesa de Toledo
# 28/803(3.49%) - Talavera de La Reina
# 29/803(3.61%) - Torrijos
# 30/803(3.74%) - Madrid - Atocha Cercanias
# 31/803(3.86%) - Leganes
# ...
